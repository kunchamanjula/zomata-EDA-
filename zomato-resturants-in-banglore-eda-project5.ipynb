# %% [markdown]
# <a href="https://www.kaggle.com/code/kunchamanjula/zomato-resturants-in-banglore-eda-project5?scriptVersionId=171726717" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# **HELLO all :) thankyou for visting my notebook .
# * please give an upvote if it is useful to you and also give me your valuable feedback on this notes
# * thankyou all:)

# %% [markdown]
# # ZOMATO RESTURANTS EDA AND VISUVALIZATON

# %% [markdown]
# # import libraries

# %%
import numpy as np  #for numeric operations
import pandas as pd #to analyse,clean,filter,manipulate ,explore datasets
import matplotlib.pyplot as plt #Data visuvalization and analysis
# %matplotlib inline
import seaborn as sns #for advance visuvalizations with matplotlib
from IPython.display import Image  #importing libary to display the image
import os #import operating system to direct the folders
import datetime # datetime is useful to date_time series analysis

# %% [markdown]
# ## ignore warnings:

# %%
import warnings
warnings.simplefilter(action="ignore",category=FutureWarning)

# %% [markdown]
# # ZOMATO :
# Zomato is an Indian multinational restaurant aggregator and food delivery company. It was founded by Deepinder Goyal and Pankaj Chaddah in 2008. Zomato provides information, menus and user-reviews of restaurants as well as food delivery options from partner restaurants in more than 1,000 Indian cities and towns, as of 2022–23. Zomato rivals Swiggy in food delivery and hyperlocal space.

# %% [markdown]
# # Zomato Resturants
# * zomato is an online food delivery app which has been running succesfully in many areas and cities over the country.
#
# # Documents needed for the registration of resturants in Zomato:
#
# * To build up a food business, Private Limited Registration, Partnership, or LLP Registration is a necessity.
# * An FSSAI Registration or FSSAI License is required by the business turnover and its activity.
# * A shop establishment registration and GST Registration are also important if one looks to partner its food business with Zomato.

# %%
from IPython.display import Image  #importing libary to display the image
import os  #import operating system to direct the folders
Image("/kaggle/input/zomato-resturants/Zomato-Partner-Registration-3.jpg")

# %% [markdown]
# # Loading Dataset
# (#by using pandas)

# %%
zomato=pd.read_csv("/kaggle/input/zomato-restaurants-dataset/zomato.csv")
zomato
# Out:
#       Unnamed: 0.1  Unnamed: 0         restaurant name     restaurant type  \
# 0                0           0            #FeelTheROLL         Quick Bites
# 1                1           1              #L-81 Cafe         Quick Bites
# 2                2           2                 #refuel                Cafe
# 3                3           3      '@ Biryani Central       Casual Dining
# 4                4           4              '@ The Bbq       Casual Dining
# ...            ...         ...                     ...                 ...
# 7100          7100        7100                  Zoey's                Cafe
# 7101          7101        7101  ZOROY Luxury Chocolate      Dessert Parlor
# 7102          7102        7102       Zu's Doner Kebaps  Takeaway, Delivery
# 7103          7103        7103                   Zyara       Casual Dining
# 7104          7104        7104                  Zyksha          Food Truck
#
# ...

# %% [markdown]
# # About Dataset
# About Dataset This dataset have 7105 rows and 12 columns.
# # featurs of dataset :
#
# * index: number of resturants  in zomato
#
# * Unnamed 0.1:number of resturants  in zomato
# * Unnamed 0:number of resturants  in zomato
# * restaurant name :name of retsurant
# * restaurant type: type of the resturants and mode of resturants
# * rate (out of 5) : rating of the resturant
# * num of ratings:number of ratings given to that resturant
# * avg cost (two people): estimation of cost of a meal for two people
# * online_order: availablity of online order or not
# * table booking: is their table booking or not
# * cuisines type: type of cusinines avaliable in resturants
# * area: area of resturant located
# * local addres:local address of the resturant
#
#
# # Goal of project:
# * zomato allow users to order food from  online of their conivence and on ease from their favorite restutrant and their likeable cusinies from home
# * to know the  discounts and offers
# *  to know the memberships
# * to know the ratings of resturants
# * to know the business of various partner resturants in zomato

# %% [markdown]
# # Data Prepartion
# *explorings rows and columns*

# %%
zomato.head() #top5 columns of dataset
# Out:
#    Unnamed: 0.1  Unnamed: 0     restaurant name restaurant type  \
# 0             0           0        #FeelTheROLL     Quick Bites
# 1             1           1          #L-81 Cafe     Quick Bites
# 2             2           2             #refuel            Cafe
# 3             3           3  '@ Biryani Central   Casual Dining
# 4             4           4          '@ The Bbq   Casual Dining
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.4               7                  200.0           No
# 1              3.9              48                  400.0          Yes
# 2              3.7              37                  400.0          Yes
# 3              2.7             135                  550.0          Yes
# 4              2.8              40                  700.0          Yes
#
#   table booking                                      cuisines type  \
# 0            No                                          Fast Food
# ...

# %%
zomato.tail(5) #bottom 5  columns of dataset
# Out:
#       Unnamed: 0.1  Unnamed: 0         restaurant name     restaurant type  \
# 7100          7100        7100                  Zoey's                Cafe
# 7101          7101        7101  ZOROY Luxury Chocolate      Dessert Parlor
# 7102          7102        7102       Zu's Doner Kebaps  Takeaway, Delivery
# 7103          7103        7103                   Zyara       Casual Dining
# 7104          7104        7104                  Zyksha          Food Truck
#
#       rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 7100              4.3             894                  600.0          Yes
# 7101              4.0              68                  250.0          Yes
# 7102              3.7              33                  350.0           No
# 7103              3.8             191                  650.0          Yes
# 7104              3.4               9                  200.0           No
#
# ...

# %%
zomato.describe()  #gives the summary about the dataset in detailed form
# Out:
#        Unnamed: 0.1   Unnamed: 0  rate (out of 5)  num of ratings  \
# count   7105.000000  7105.000000      7037.000000     7105.000000
# mean    3552.000000  3552.000000         3.514253      188.921042
# std     2051.181164  2051.181164         0.463249      592.171049
# min        0.000000     0.000000         1.800000        1.000000
# 25%     1776.000000  1776.000000         3.200000       16.000000
# 50%     3552.000000  3552.000000         3.500000       40.000000
# 75%     5328.000000  5328.000000         3.800000      128.000000
# max     7104.000000  7104.000000         4.900000    16345.000000
#
#        avg cost (two people)
# count            7048.000000
# mean              540.286464
# std               462.902305
# min                40.000000
# 25%               300.000000
# 50%               400.000000
# 75%               600.000000
# max              6000.000000

# %%
zomato.info()#gives the information like datatypes and null count for every columns and rows in dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7105 entries, 0 to 7104
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           7105 non-null   int64
#  1   Unnamed: 0             7105 non-null   int64
#  2   restaurant name        7105 non-null   object
#  3   restaurant type        7105 non-null   object
#  4   rate (out of 5)        7037 non-null   float64
#  5   num of ratings         7105 non-null   int64
#  6   avg cost (two people)  7048 non-null   float64
#  7   online_order           7105 non-null   object
#  8   table booking          7105 non-null   object
#  9   cuisines type          7105 non-null   object
#  10  area                   7105 non-null   object
#  11  local address          7105 non-null   object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 666.2+ KB

# %%
type(zomato) #dataset type is  dataframe as it is the combination of  mutlple series
# Out:
# pandas.core.frame.DataFrame

# %%
type(zomato["area"])  #single column in dataset will be consider as series
# Out:
# pandas.core.series.Series

# %%
zomato.index  #index of dataframe from starting to end range will be shown
# Out:
# RangeIndex(start=0, stop=7105, step=1)

# %%
zomato.columns  #columns of the dataframe will be appear
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'restaurant name', 'restaurant type',
#        'rate (out of 5)', 'num of ratings', 'avg cost (two people)',
#        'online_order', 'table booking', 'cuisines type', 'area',
#        'local address'],
#       dtype='object')

# %%
zomato.values #values in dataframe will appear
# Out:
# array([[0, 0, '#FeelTheROLL', ..., 'Fast Food', 'Bellandur', 'Bellandur'],
#        [1, 1, '#L-81 Cafe', ..., 'Fast Food, Beverages',
#         'Byresandra,Tavarekere,Madiwala', 'HSR'],
#        [2, 2, '#refuel', ..., 'Cafe, Beverages', 'Bannerghatta Road',
#         'Bannerghatta Road'],
#        ...,
#        [7102, 7102, "Zu's Doner Kebaps", ...,
#         'Turkish, Fast Food, Biryani, Chinese', 'Malleshwaram',
#         'RT Nagar'],
#        [7103, 7103, 'Zyara', ..., 'North Indian, Mughlai, Chinese',
#         'Kammanahalli', 'HBR Layout'],
#        [7104, 7104, 'Zyksha', ..., 'Fast Food', 'Bannerghatta Road',
#         'South Bangalore']], dtype=object)

# %%
zomato.set_index("restaurant name",inplace=True)#for setting customized index

# %%
zomato.head()
# Out:
#                     Unnamed: 0.1  Unnamed: 0 restaurant type  rate (out of 5)  \
# restaurant name
# #FeelTheROLL                   0           0     Quick Bites              3.4
# #L-81 Cafe                     1           1     Quick Bites              3.9
# #refuel                        2           2            Cafe              3.7
# '@ Biryani Central             3           3   Casual Dining              2.7
# '@ The Bbq                     4           4   Casual Dining              2.8
#
#                     num of ratings  avg cost (two people) online_order  \
# restaurant name
# #FeelTheROLL                     7                  200.0           No
# #L-81 Cafe                      48                  400.0          Yes
# #refuel                         37                  400.0          Yes
# '@ Biryani Central             135                  550.0          Yes
# '@ The Bbq                      40                  700.0          Yes
#
# ...

# %%
zomato.reset_index(inplace=True)

# %% [markdown]
# # Data cleaning
# *Data cleaning is the process of fixing or removing incorrect, corrupted, incorrectly formatted, duplicate, or incomplete data within a dataset.

# %% [markdown]
# # benfitis of data cleaning
#
# * Error free data
# * Acurracy and effiency
# * Data quality
# * Data consistency

# %%
mask=zomato.isnull()  #isnullfunctions checks for null in dataset and gives boolean output 
zomato[mask]     #mask is variable which stores True values
# in this dataset doesnt have any null values so it showing NaN
# Out:
#      restaurant name  Unnamed: 0.1  Unnamed: 0 restaurant type  \
# 0                NaN           NaN         NaN             NaN
# 1                NaN           NaN         NaN             NaN
# 2                NaN           NaN         NaN             NaN
# 3                NaN           NaN         NaN             NaN
# 4                NaN           NaN         NaN             NaN
# ...              ...           ...         ...             ...
# 7100             NaN           NaN         NaN             NaN
# 7101             NaN           NaN         NaN             NaN
# 7102             NaN           NaN         NaN             NaN
# 7103             NaN           NaN         NaN             NaN
# 7104             NaN           NaN         NaN             NaN
#
#       rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0                 NaN             NaN                    NaN          NaN
# ...

# %%
print(zomato.isnull().sum()) # null values in some columns(rating and avg cost)
# Out:
# restaurant name           0
# Unnamed: 0.1              0
# Unnamed: 0                0
# restaurant type           0
# rate (out of 5)          68
# num of ratings            0
# avg cost (two people)    57
# online_order              0
# table booking             0
# cuisines type             0
# area                      0
# local address             0
# dtype: int64

# %% [markdown]
# * NOTE : [if nulls are present in dataset then treat them with fillna() or dropna()]

# %%
zomato["rate (out of 5)"].mean() #to fill nullvalues in age columns we are taking average value of rate
# Out:
# 3.5142532329117526

# %%
zomato["rate (out of 5)"]=zomato["rate (out of 5)"].fillna(3.5) #filling null values with mean value of rating beacuse error  and null free data can be easily analyized

# %%
zomato["avg cost (two people)"].mean() #finding unique values in rating column
# Out:
# 540.2864642451759

# %%
zomato["avg cost (two people)"]=zomato["avg cost (two people)"].fillna(540) #filling null values with mean value of cost beacuse error  and null free data can be easily analyized

# %%
print(zomato.isnull().sum()) # null values in some columns(rating and avg cost) #error and null free data
# Out:
# restaurant name          0
# Unnamed: 0.1             0
# Unnamed: 0               0
# restaurant type          0
# rate (out of 5)          0
# num of ratings           0
# avg cost (two people)    0
# online_order             0
# table booking            0
# cuisines type            0
# area                     0
# local address            0
# dtype: int64

# %%
del zomato["Unnamed: 0.1"] #deleting extra column

# %%
del zomato["Unnamed: 0"] #deleting extra column

# %%
zomato.duplicated(subset=["restaurant name","restaurant type","rate (out of 5)","num of ratings","avg cost (two people)","online_order","table booking","cuisines type","area","local address"])
#checks for duplicates in this dataset
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7100    False
# 7101    False
# 7102    False
# 7103    False
# 7104    False
# Length: 7105, dtype: bool

# %%
# if there is duplicates treat it with drop_dupliacates for error free dataset
#checks for duplicates in this dataset
zomato.drop_duplicates(subset=["restaurant name","restaurant type","rate (out of 5)","num of ratings","avg cost (two people)","online_order","table booking","cuisines type","area","local address"],inplace=True)
#checks for duplicates in this dataset
len(zomato)   #the length before drop duplicates and after is same therefore there are no dupliacates in dataset
#if length and drop duplicates changes then there are duplicates
# Out:
# 7105

# %%
zomato.nunique()  #give the count of unique numbers in dataset by columns vise
# Out:
# restaurant name          7105
# restaurant type            81
# rate (out of 5)            31
# num of ratings            935
# avg cost (two people)      66
# online_order                2
# table booking               2
# cuisines type            2175
# area                       30
# local address              90
# dtype: int64

# %%
zomato['area'].unique()  #give the unique  array in dataset  with respect to column given
# Out:
# array(['Bellandur', 'Byresandra,Tavarekere,Madiwala', 'Bannerghatta Road',
#        'Marathahalli', 'Whitefield', 'Banashankari', 'Indiranagar',
#        'Electronic City', 'Old Airport Road', 'Basavanagudi',
#        'Malleshwaram', 'Kalyan Nagar', 'Rajajinagar', 'Brigade Road',
#        'Koramangala 7th Block', 'JP Nagar', 'Lavelle Road',
#        'Sarjapur Road', 'HSR', 'Frazer Town', 'Kammanahalli',
#        'New BEL Road', 'Jayanagar', 'Brookefield',
#        'Koramangala 5th Block', 'Koramangala 4th Block',
#        'Koramangala 6th Block', 'Church Street', 'MG Road',
#        'Residency Road'], dtype=object)

# %%
zomato["restaurant type"].unique()  #give the unique  array in dataset  with respect to column given
# Out:
# array(['Quick Bites', 'Cafe', 'Casual Dining', 'Takeaway, Delivery',
#        'Bar, Casual Dining', 'Fine Dining', 'Pub', 'Casual Dining, Bar',
#        'Delivery', 'Kiosk', 'Food Court', 'Microbrewery', 'Bar', 'Mess',
#        'Bakery', 'Dessert Parlor', 'Beverage Shop', 'Sweet Shop', 'Dhaba',
#        'Cafe, Quick Bites', 'Microbrewery, Casual Dining',
#        'Dessert Parlor, Beverage Shop', 'Bar, Lounge',
#        'Quick Bites, Mess', 'Food Truck', 'Lounge, Bar',
#        'Cafe, Dessert Parlor', 'Quick Bites, Beverage Shop',
#        'Pub, Casual Dining', 'Pub, Microbrewery',
#        'Sweet Shop, Quick Bites', 'Cafe, Bakery', 'Fine Dining, Bar',
#        'Bar, Pub', 'Bakery, Quick Bites', 'Bakery, Beverage Shop',
#        'Bakery, Dessert Parlor', 'Takeaway', 'Lounge',
#        'Microbrewery, Lounge', 'Lounge, Microbrewery',
#        'Casual Dining, Microbrewery', 'Casual Dining, Pub',
#        'Bakery, Cafe', 'Casual Dining, Cafe', 'Microbrewery, Pub',
# ...

# %%
zomato["rate (out of 5)"].unique()  #give the unique  array in dataset  with respect to column given
# Out:
# array([3.4, 3.9, 3.7, 2.7, 2.8, 4.1, 3.2, 3.5, 4.4, 4.2, 4. , 4.3, 3.1,
#        3.6, 3.3, 2.9, 3. , 3.8, 2.5, 4.6, 1.8, 2.4, 4.5, 4.9, 2.1, 4.7,
#        2.6, 4.8, 2. , 2.3, 2.2])

# %% [markdown]
#  # Data performing:
# the process of systematically applying the statstical,numerical and logic techinques to describe and illustrate and evaluate data

# %%
zomato.shape  #shape of dataframe
# Out:
# (7105, 10)

# %%
zomato.size  #gives the size of dataframe
# Out:
# 71050

# %%
zomato.ndim  #this dataframe is 2d array
# Out:
# 2

# %% [markdown]
# #  Exploratory Data  Analysis & Visualization
# * EDA plays an important role in Data Analysis
# * Explanatory data analytics focuses on all the parts of context, mainly the why and how. An outcome can be statistically calculated, modeled, or visualized to tell you the likelihood of certain events based on preconceived variables.

# %%
zomato.head()
# Out:
#       restaurant name restaurant type  rate (out of 5)  num of ratings  \
# 0        #FeelTheROLL     Quick Bites              3.4               7
# 1          #L-81 Cafe     Quick Bites              3.9              48
# 2             #refuel            Cafe              3.7              37
# 3  '@ Biryani Central   Casual Dining              2.7             135
# 4          '@ The Bbq   Casual Dining              2.8              40
#
#    avg cost (two people) online_order table booking  \
# 0                  200.0           No            No
# 1                  400.0          Yes            No
# 2                  400.0          Yes            No
# 3                  550.0          Yes            No
# 4                  700.0          Yes            No
#
#                                        cuisines type  \
# 0                                          Fast Food
# 1                               Fast Food, Beverages
# 2                                    Cafe, Beverages
# ...

# %%
zomato["num of ratings"].max() #gives maxiumum  rating value in dataset
# Out:
# 16345

# %%
zomato["avg cost (two people)"].min()  #gives minimum cost value in dataset
# Out:
# 40.0

# %%
zomato["num of ratings"].mean()  #gives avearge of column no.of ratings in dataframe
# Out:
# 188.9210415200563

# %%
 zomato.sort_values("rate (out of 5)") #ascending sorting based on lowest rating column in a dataset
# Out:
#                                         restaurant name     restaurant type  \
# 231                    Alibi - Maya International Hotel       Casual Dining
# 2296                                      Fusion Lounge              Lounge
# 708                                             Bhagini       Casual Dining
# 3705                                  Madurai Idly Shop         Quick Bites
# 3837                                      Mast Kalandar       Casual Dining
# ...                                                 ...                 ...
# 4827                                       Punjab Grill       Casual Dining
# 6496                                   The Pizza Bakery       Casual Dining
# 5271  SantÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃ...       Casual Dining
# 1035                        Byg Brewski Brewing Company        Microbrewery
# 466                      Asia Kitchen By Mainland China  Casual Dining, Bar
#
# ...

# %%
zomato.sort_values("num of ratings",ascending=False)  #descending sorting based on no.of ratings  column in a dataset
# Out:
#                                     restaurant name     restaurant type  \
# 1035                    Byg Brewski Brewing Company        Microbrewery
# 6665                                           Toit        Microbrewery
# 6242                                The Black Pearl  Casual Dining, Bar
# 770                                     Big Pitcher   Pub, Microbrewery
# 423                           Arbor Brewing Company   Pub, Microbrewery
# ...                                             ...                 ...
# 1183                                Cake of the Day              Bakery
# 2247                                     Fresh Bowl         Quick Bites
# 2434  Great Moments - Hotel Bangalore International  Casual Dining, Bar
# 2588  Height's Cafe - Hotel Bangalore International       Casual Dining
# 2968                                           Irie       Casual Dining
#
#       rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# ...

# %%
zomato.sort_index()  #sorting based on index column in a dataset (back to original dataset)
# Out:
#              restaurant name     restaurant type  rate (out of 5)  \
# 0               #FeelTheROLL         Quick Bites              3.4
# 1                 #L-81 Cafe         Quick Bites              3.9
# 2                    #refuel                Cafe              3.7
# 3         '@ Biryani Central       Casual Dining              2.7
# 4                 '@ The Bbq       Casual Dining              2.8
# ...                      ...                 ...              ...
# 7100                  Zoey's                Cafe              4.3
# 7101  ZOROY Luxury Chocolate      Dessert Parlor              4.0
# 7102       Zu's Doner Kebaps  Takeaway, Delivery              3.7
# 7103                   Zyara       Casual Dining              3.8
# 7104                  Zyksha          Food Truck              3.4
#
#       num of ratings  avg cost (two people) online_order table booking  \
# 0                  7                  200.0           No            No
# ...

# %%
zomato.iloc[25]   #acessing location based on index
# Out:
# restaurant name                                 20 Feet High
# restaurant type                           Casual Dining, Bar
# rate (out of 5)                                          4.0
# num of ratings                                           932
# avg cost (two people)                                 1000.0
# online_order                                             Yes
# table booking                                            Yes
# cuisines type            American, Continental, Steak, Salad
# area                                            Brigade Road
# local address                                  Church Street
# Name: 25, dtype: object

# %%
zomato.iloc[20:30:2]  #accesing dataframes with iloc accessor where range is excluive
# Out:
#                               restaurant name     restaurant type  \
# 20                         1992 Chats - Space         Quick Bites
# 22                               1TO3 Kitchen            Delivery
# 24              20 Char - Sterlings MAC Hotel  Casual Dining, Bar
# 26  21 C - La Marvella Sarovar Premiere Hotel       Casual Dining
# 28                     24 Hours Cake Delivery            Delivery
#
#     rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 20              3.7              33                  200.0          Yes
# 22              3.1              11                  800.0           No
# 24              4.0             419                 1400.0          Yes
# 26              3.6              15                 1000.0           No
# 28              3.3               4                  700.0           No
#
#    table booking                                      cuisines type  \
# ...

# %%
zomato.nlargest(3,"avg cost (two people)") #top 3 highest dataframes in dataset
# Out:
#                              restaurant name restaurant type  rate (out of 5)  \
# 3561  Le Cirque Signature - The Leela Palace     Fine Dining              4.3
# 5090              Royal Afghan - ITC Windsor     Fine Dining              4.3
# 3761                  Malties - Radisson Blu          Lounge              4.3
#
#       num of ratings  avg cost (two people) online_order table booking  \
# 3561             126                 6000.0           No           Yes
# 5090             413                 5000.0           No           Yes
# 3761              53                 4500.0           No            No
#
#                cuisines type          area     local address
# 3561         French, Italian   Indiranagar  Old Airport Road
# 5090   North Indian, Mughlai  Malleshwaram       Sankey Road
# 3761  Continental, Fast Food  Marathahalli      Marathahalli

# %%
zomato.nsmallest(5,"num of ratings") #bottom 5 smallest no.of ratings values in dataset
# Out:
#                                     restaurant name     restaurant type  \
# 2968                                           Irie       Casual Dining
# 2434  Great Moments - Hotel Bangalore International  Casual Dining, Bar
# 2588  Height's Cafe - Hotel Bangalore International       Casual Dining
# 28                           24 Hours Cake Delivery            Delivery
# 47                                         4 States          Food Court
#
#       rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 2968              3.2               1                  800.0           No
# 2434              3.2               2                 1100.0           No
# 2588              3.2               2                 1000.0          Yes
# 28                3.3               4                  700.0           No
# 47                3.2               4                  400.0           No
#
#      table booking              cuisines type           area     local address
# ...

# %%
zomato[5:15:2]  #slicing[start:stop:step]
# Out:
#                          restaurant name     restaurant type  rate (out of 5)  \
# 5                                   '@99  Takeaway, Delivery              3.4
# 7                   '@North Parontha Hut  Takeaway, Delivery              2.8
# 9   100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C       Casual Dining              3.7
# 11                    1131 Bar + Kitchen  Bar, Casual Dining              4.4
# 13                         1441 Pizzeria       Casual Dining              4.1
#
#     num of ratings  avg cost (two people) online_order table booking  \
# 5               37                  200.0           No            No
# 7               40                  300.0           No            No
# 9               41                  450.0           No            No
# 11            2861                 1500.0           No           Yes
# 13             119                  800.0          Yes            No
#
#                                 cuisines type                            area  \
# ...

# %%
zomato.set_index(["restaurant type","area"],inplace=True)
zomato#multi level indexing where platform acts as parental hireacy index and country acts as child hireachy level indexing
# Out:
#                                                           restaurant name  \
# restaurant type    area
# Quick Bites        Bellandur                                 #FeelTheROLL
#                    Byresandra,Tavarekere,Madiwala              #L-81 Cafe
# Cafe               Bannerghatta Road                              #refuel
# Casual Dining      Marathahalli                        '@ Biryani Central
#                    Bellandur                                   '@ The Bbq
# ...                                                                   ...
# Cafe               Bellandur                                       Zoey's
# Dessert Parlor     Brigade Road                    ZOROY Luxury Chocolate
# Takeaway, Delivery Malleshwaram                         Zu's Doner Kebaps
# Casual Dining      Kammanahalli                                     Zyara
# Food Truck         Bannerghatta Road                               Zyksha
#
# ...

# %%
zomato.reset_index(inplace=True)

# %% [markdown]
# # Data visuvalization

# %% [markdown]
# # Question and Answers
# * by using different libararies to perform EDA and VISUALIZATION

# %% [markdown]
# # 1.what are the budget friendly resturants for users with good taste in banglore ?

# %%
budget_friendly=zomato[["restaurant name","avg cost (two people)","rate (out of 5)"]].sort_values(by=["avg cost (two people)","rate (out of 5)"],ascending=[True,False]).head()
budget_friendly
# Out:
#                restaurant name  avg cost (two people)  rate (out of 5)
# 5850  Srinidhi Sagar Food Line                   40.0              3.7
# 5849     Srinidhi Sagar Deluxe                   40.0              3.6
# 5303               Savera Cafe                   50.0              3.6
# 4230         Nellore Dosa Camp                   70.0              3.3
# 4144                   Namaste                   70.0              2.8

# %%
sns.barplot(x=budget_friendly["avg cost (two people)"],y=budget_friendly["restaurant name"],hue=budget_friendly["rate (out of 5)"],data=zomato)
plt.title('Budget Friendly Restaurants in Banglore  w.r.t  Rating and cost')
plt.show()

# %% [markdown]
# # 2.Recommend resturant type for new enterpretenur?

# %% [markdown]
# **TOP 10 Recommended resturant types for new resturant owner**

# %%
top_resturant_type=zomato['restaurant type'].value_counts().head(10) #getting top 10 retutrant types by using sort values
top_resturant_type
# Out:
# restaurant type
# Quick Bites           2840
# Casual Dining         1634
# Cafe                   403
# Delivery               358
# Takeaway, Delivery     289
# Dessert Parlor         217
# Bakery                 154
# Casual Dining, Bar     123
# Beverage Shop          118
# Bar                     82
# Name: count, dtype: int64

# %%
explode=[0.1,0,0,0,0,0.3,0.3,0.3,0.3,0.3]
plt.pie(x=top_resturant_type,labels=top_resturant_type.index,autopct="%1.1f%%",explode=explode) #plotting pie chart to get the visualization of top 10 resturant types
plt.title('Top 10 Resturant types in Banglore')

plt.show()

# %% [markdown]
# **BOTTOM 7 NOT  Recommended resturant types for new resturant owner**

# %%
bottom_resturant_type=zomato['restaurant type'].value_counts().tail(7)#getting BOTTOM 7 retutrant types by using sort values
bottom_resturant_type
# Out:
# restaurant type
# Cafe, Lounge             1
# Cafe, Bar                1
# Microbrewery, Lounge     1
# Bakery, Beverage Shop    1
# Bar, Pub                 1
# Quick Bites, Mess        1
# Club, Casual Dining      1
# Name: count, dtype: int64

# %%
plt.pie(x=bottom_resturant_type,labels=bottom_resturant_type.index,autopct="%1.1f%%")#plotting pie chart to get the visualization BOTTOM 7 resturant types
plt.title('Bottom 7 Resturant types in Banglore')

plt.show()

# %% [markdown]
# # 3. plot the barchart to  withrespect to index and differeint varaibles in dataset?

# %%
zomato_variables = ["rate (out of 5)","avg cost (two people)"]

fig, axs = plt.subplots(2, figsize=(12, 10))

for index, ax in enumerate(fig.axes):
    sns.barplot(y=zomato[zomato_variables[index]].value_counts(), 
                x=zomato[zomato_variables[index]].value_counts().index, ax=ax)
    ax.set_ylabel("Count")
    ax.set_xlabel(zomato_variables[index])

plt.show()

# %% [markdown]
# # 4.What are the best type of cuisine most liked by zomato users?

# %%
cuisine=zomato['cuisines type'].value_counts().head(10) #getting the unique values by using value_counts
cuisine
# Out:
# cuisines type
# North Indian, Chinese                  421
# North Indian                           420
# South Indian                           348
# Fast Food                              140
# South Indian, North Indian, Chinese    128
# Biryani                                122
# Bakery, Desserts                        97
# Desserts                                87
# Cafe                                    85
# Bakery                                  77
# Name: count, dtype: int64

# %%
plt.pie(cuisine,labels=cuisine.index,autopct='%1.1f%%') #piechart for the top cuisines are most liked by zomato  users in banglore

plt.title('Popular cuisines in Bangalore') #Plotting pie chart to get better visvalization and analysis by using matplotlib

plt.show()

# %%
zomato.reset_index(inplace=True)

# %%
zomato.head()
# Out:
#    index restaurant type                            area     restaurant name  \
# 0      0     Quick Bites                       Bellandur        #FeelTheROLL
# 1      1     Quick Bites  Byresandra,Tavarekere,Madiwala          #L-81 Cafe
# 2      2            Cafe               Bannerghatta Road             #refuel
# 3      3   Casual Dining                    Marathahalli  '@ Biryani Central
# 4      4   Casual Dining                       Bellandur          '@ The Bbq
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.4               7                  200.0           No
# 1              3.9              48                  400.0          Yes
# 2              3.7              37                  400.0          Yes
# 3              2.7             135                  550.0          Yes
# 4              2.8              40                  700.0          Yes
#
#   table booking                                      cuisines type  \
# ...

# %% [markdown]
# # 5.how many resturants has online booking options in banglore?

# %%
online=zomato["online_order"].value_counts()
online
# Out:
# online_order
# Yes    3727
# No     3378
# Name: count, dtype: int64

# %%
plt.pie(online,labels=online.index,autopct='%1.1f%%')
cen_cir=plt.Circle((0,0),0.70,fc='white')
fig=plt.gcf()
fig.gca().add_artist(cen_cir)
plt.axis('equal')
plt.title('Percentage of restaurants that offer online order')
plt.show()

# %% [markdown]
# * There are equal number of resturants which has online bookings and also not  online booking resturants

# %% [markdown]
# # 6.provide the top 10 list of resturants in banglore based on their ratings and reviews given by zomato users?

# %%
top_rated=zomato[['restaurant name','num of ratings','rate (out of 5)']].sort_values(by=['num of ratings','rate (out of 5)'],ascending=[False,False]).head(10)
top_rated
# Out:
#                   restaurant name  num of ratings  rate (out of 5)
# 1035  Byg Brewski Brewing Company           16345              4.9
# 6665                         Toit           14956              4.7
# 6242              The Black Pearl           10413              4.7
# 770                   Big Pitcher            9272              4.6
# 423         Arbor Brewing Company            8375              4.5
# 4808               Prost Brew Pub            7854              4.5
# 1489         Church Street Social            7544              4.3
# 2632                         Hoot            7193              4.2
# 2149                     Flechazo            7154              4.7
# 6380    The Hole in the Wall Cafe            7113              4.6

# %%
sns.barplot(x=top_rated['num of ratings'],y=top_rated['restaurant name'],hue=top_rated['rate (out of 5)'])
plt.title('Top restaurants based on reviws and ratings')
plt.show()

# %% [markdown]
# # 7.provide the top 10 fastfood and beverages restaurants in Bangalore?

# %%
fastfood_bev=zomato.groupby('cuisines type').get_group('Fast Food, Beverages')[['restaurant name','rate (out of 5)','num of ratings']].sort_values(by=['rate (out of 5)','num of ratings'],ascending=[False,False]).head(10)
fastfood_bev
# Out:
#      restaurant name  rate (out of 5)  num of ratings
# 1904            Doof              4.0             371
# 6398           The J              4.0             133
# 1         #L-81 Cafe              3.9              48
# 1291      Chai Point              3.8              94
# 4680     Peek a Brew              3.8              29
# 5922  Sulaimani Chai              3.8              21
# 6014           Symas              3.7              34
# 5601     Snack Magic              3.7              25
# 1592        Cravingz              3.7              17
# 1542     Coffee Bike              3.7              15

# %%
sns.barplot(x=fastfood_bev['num of ratings'],y=fastfood_bev['restaurant name'],hue=fastfood_bev['rate (out of 5)'])
plt.title('Top 10 fastfood and bevaerages Restaurant In bangalore')
plt.show()

# %% [markdown]
# # 8.show the popular 5 cuisine  in specfic area of banglore?

# %%
area1=zomato.groupby('area')['cuisines type'].value_counts().head(5)
area1
# Out:
# area          cuisines type
# Banashankari  South Indian                           48
#               North Indian, Chinese                  20
#               North Indian                           19
#               Fast Food                              11
#               South Indian, North Indian, Chinese     8
# Name: count, dtype: int64

# %%
plt.pie(area1, labels=area1.index,autopct='%1.1f%%')
plt.title('Area wise cuisine')
plt.show()

# %% [markdown]
# # 9.Determine the percentage of restaurants that currently offer table booking service

# %%
table_booking=zomato["table booking"].value_counts()
table_booking
# Out:
# table booking
# No     6361
# Yes     744
# Name: count, dtype: int64

# %%
plt.pie(table_booking,labels=table_booking.index,autopct='%1.1f%%')
cen_cir=plt.Circle((0,0),0.70,fc='white')
fig=plt.gcf()
fig.gca().add_artist(cen_cir)
plt.axis('equal')
plt.title('Percentage of restaurants that offer table booking')
plt.show()

# %% [markdown]
# # 10.provide the list of average cost of meal in specific areas in banglore?

# %%
zomato.groupby(by="area")["avg cost (two people)"].agg(func=["mean", "median", "max", "min"]).sort_values(by="mean", ascending=False)#
# Out:
#                                       mean  median     max    min
# area
# Lavelle Road                    861.631206   550.0  4100.0   50.0
# Brigade Road                    836.271552   600.0  4000.0   40.0
# Church Street                   747.272727   500.0  4000.0  100.0
# Whitefield                      702.720307   500.0  3000.0  150.0
# Indiranagar                     669.956044   450.0  6000.0  100.0
# Old Airport Road                623.406593   450.0  2400.0  150.0
# Malleshwaram                    578.009950   400.0  5000.0  100.0
# MG Road                         577.500000   475.0  2000.0  150.0
# Koramangala 4th Block           568.333333   400.0  3000.0   40.0
# Bellandur                       545.734072   450.0  2500.0  100.0
# Brookefield                     526.834382   400.0  3000.0  100.0
# Marathahalli                    520.884615   400.0  4500.0  100.0
# Kammanahalli                    513.230769   450.0  1800.0  100.0
# ...

# %% [markdown]
# # 11.list of areas which provides most classic and most costed food?

# %%
 top_cost=zomato.groupby(by="area")["avg cost (two people)"].agg(func=[ "max"]).sort_values(by="max",ascending=False).head(5)
top_cost
# Out:
#                  max
# area
# Indiranagar   6000.0
# Malleshwaram  5000.0
# Marathahalli  4500.0
# Lavelle Road  4100.0
# Brigade Road  4000.0

# %% [markdown]
# #  SUMMARY:

# %% [markdown]
# * by this EDA and vizuvalizations we can analyse that:
# 1. helpful for future new enterprenurs who wamts to open resturants by getting the guide of cuisines and areas for better business.
# 2. to zomato users who order online will get idea about the resutarnts based on the ratings and reviwes
# 3. users can know the average amount to spend on food
# 4. conviencly and easely know the place where their favorite cuisines are offering with afforables prices
# 5. ratings and reviews are more useful for users and both resturants
# 6. to know the popular resturant in their near by area
# 7. to preplan the resturant visit by using table booking
